# %% [markdown]
# # Artifical neural network for linear regression

# %% [markdown]
# ### Importing the libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Creating the dataset

# %%
# Make the dataset
N = 1000
X = np.random.random((N, 2)) * 6 - 3 # uniformly distributed between (-3, +3)
y = np.cos(2*X[:,0]) + np.cos(3*X[:,1])

# %% [markdown]
# This implements the function:
#
# $$ y = \cos(2x_1) + cos(3x_2) $$

# %%
# Plot it
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], y)
# plt.show()

# %% [markdown]
# ## Part 2 - Building the model

# %%
# Build the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(128, input_shape=(2,), activation='relu'),
  tf.keras.layers.Dense(1)
])

# %% [markdown]
# ## PART 3 - Training the Artificial Neural Network

# %% [markdown]
# ### Compiling the model

# %%
# Compile and fit
opt = tf.keras.optimizers.Adam(0.01)
model.compile(optimizer=opt, loss='mse')

# %% [markdown]
# ### Training the model

# %%
r = model.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 1ms/step - loss: 1.0954
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9665
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9642
# Epoch 4/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9275
# Epoch 5/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8620
# Epoch 6/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8752
# Epoch 7/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6871
# Epoch 8/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6557
# Epoch 9/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5849
# Epoch 10/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5385
# Epoch 11/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5382
# Epoch 12/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4572
# Epoch 13/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4881
# Epoch 14/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4619
# Epoch 15/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4613
# Epoch 16/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4462
# Epoch 17/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4494
# Epoch 18/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4423
# Epoch 19/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4921
# Epoch 20/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5062
# Epoch 21/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4162
# Epoch 22/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4246
# Epoch 23/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4141
# Epoch 24/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3781
# Epoch 25/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3846
# Epoch 26/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5033
# Epoch 27/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3995
# Epoch 28/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3620
# Epoch 29/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4225
# Epoch 30/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3390
# Epoch 31/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3677
# Epoch 32/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3825
# Epoch 33/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3054
# Epoch 34/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2809
# Epoch 35/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2438
# Epoch 36/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2439
# Epoch 37/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2614
# Epoch 38/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1795
# Epoch 39/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1707
# Epoch 40/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1653
# Epoch 41/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1623
# Epoch 42/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1286
# Epoch 43/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1065
# Epoch 44/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1048
# Epoch 45/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0811
# Epoch 46/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0910
# Epoch 47/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0676
# Epoch 48/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0570
# Epoch 49/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0594
# Epoch 50/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0472
# Epoch 51/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0460
# Epoch 52/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0333
# Epoch 53/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0277
# Epoch 54/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0326
# Epoch 55/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0225
# Epoch 56/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0250
# Epoch 57/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0160
# Epoch 58/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0214
# Epoch 59/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0211
# Epoch 60/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0169
# Epoch 61/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0136
# Epoch 62/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0203
# Epoch 63/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0144
# Epoch 64/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0318
# Epoch 65/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0155
# Epoch 66/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0115
# Epoch 67/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 68/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0174
# Epoch 69/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0130
# Epoch 70/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0104
# Epoch 71/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0185
# Epoch 72/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0098
# Epoch 73/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0105
# Epoch 74/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0088
# Epoch 75/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0120
# Epoch 76/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0150
# Epoch 77/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0267
# Epoch 78/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0292
# Epoch 79/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0127
# Epoch 80/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0195
# Epoch 81/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0123
# Epoch 82/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0171
# Epoch 83/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0144
# Epoch 84/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0150
# Epoch 85/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0175
# Epoch 86/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0081
# Epoch 87/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0166
# Epoch 88/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0086
# Epoch 89/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0068
# Epoch 90/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0172
# Epoch 91/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0121
# Epoch 92/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0157
# Epoch 93/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0406
# Epoch 94/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0089
# Epoch 95/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0066
# Epoch 96/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0109
# Epoch 97/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0093
# Epoch 98/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0144
# Epoch 99/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0242
# Epoch 100/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0113

# %%
# Plot the loss
plt.plot(r.history['loss'], label='loss')

# %% [markdown]
# ## Part 4 - Making the predictions

# %%
# Plot the prediction surface
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], y)

# surface plot
line = np.linspace(-3, 3, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()

# %%
# Can it extrapolate?
# Plot the prediction surface
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], y)

# surface plot
line = np.linspace(-5, 5, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()
