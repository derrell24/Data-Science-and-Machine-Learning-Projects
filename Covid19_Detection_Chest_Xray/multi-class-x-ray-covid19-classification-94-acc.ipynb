# %% [markdown]
# ### Dataset Information
#
# In my analysis the following dataset is used
# * **COVID-19 RADIOGRAPHY DATABASE**
# <br> A team of researchers from Qatar University, Doha, Qatar, and the University of Dhaka, Bangladesh along with their collaborators from Pakistan and Malaysia in collaboration with medical doctors have created a database of chest X-ray images for COVID-19 positive cases along with Normal and Viral Pneumonia images. The database consists of 3616 COVID-19 positive cases along with 10,192 Normal, 6012 Lung Opacity (Non-COVID lung infection), and 1345 Viral Pneumonia images.<br>
# [Link to the dataset](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
#
# **If you like my work please upvote**

# %% [markdown]
# # **1.Importing Libraries**

# %%
import os 
import pandas as pd
import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import seaborn as sns
import numpy as np
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, BatchNormalization, MaxPooling2D,GlobalAveragePooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
from tensorflow.keras.applications.densenet import DenseNet169
import cv2

# %% [markdown]
# # **2. Creating datasets**

# %%
def generate_dataset_from_directory(folder_path, size = 224,batch_size = 32): 

    '''fetch all out test data from directory'''

    image_generator = ImageDataGenerator(
        samplewise_center=True, #Set each sample mean to 0.
        samplewise_std_normalization= True, # Divide each input by its standard deviation]
        #rescale=1./255,
        validation_split = 0.3
    )

    #create training and testing datasets
    train_data = image_generator.flow_from_directory(directory = 
        folder_path,
        class_mode="categorical",
        color_mode="rgb",
        target_size = (size, size),
        batch_size  = batch_size,
        shuffle=True,
        seed=123,
        subset="training"
    )

    #create training and testing datasets
    val_data = image_generator.flow_from_directory(directory = 
        folder_path,
        class_mode="categorical",
        color_mode="rgb",
        target_size = (size, size),
        batch_size  = batch_size,
        shuffle=True,
        seed=123,
        subset="validation"
    )


#     total_images = train_data.n  
#     steps = total_images//batch_size 
#     xtrain , ytrain = [] , []
#     for i in range(steps):
#         a , b = train_data.next()
#         xtrain.extend(a) 
#         ytrain.extend(b)

#     total_images = val_data.n  
#     steps = total_images//batch_size 
#     xval , yval = [] , []
#     for i in range(steps):
#         a , b = val_data.next()
#         xval.extend(a) 
#         yval.extend(b)

    return train_data, val_data

# %%
folder_path = '../input/covid19-radiography-database/COVID-19_Radiography_Dataset/'
train_data, val_data = generate_dataset_from_directory(
    folder_path, size = 128,batch_size = 32)
# Out:
# Found 14818 images belonging to 4 classes.
# Found 6347 images belonging to 4 classes.

# %% [markdown]
# # **3.Exploratory Data Analysis**

# %%
class_names = train_data.class_indices
print(class_names)
# Out:
# {'COVID': 0, 'Lung_Opacity': 1, 'Normal': 2, 'Viral Pneumonia': 3}

# %%
classes = list(class_names.keys())
print(classes)
# Out:
# ['COVID', 'Lung_Opacity', 'Normal', 'Viral Pneumonia']

# %%
images,labels = next(train_data)
labels = np.argmax(labels, axis=1)
class_dict = train_data.class_indices
class_dict_inv = dict((v, k) for k, v in class_dict.items())
y_names = [class_dict_inv[key] for key in labels]

# %%
#Lets visualize the augmented images
plt.figure(figsize=(10, 10))
for image in images:
    j  = 0
    for i in range(4):
        ax = plt.subplot(1, 4, i+1)
        for k in range(len(labels)):
            if labels[k] == j:
                plt.imshow(images[k])
                plt.title(classes[i])
                plt.axis("off")
                break
        j = j+1

# %%
# Investing single image
raw_image = images[k]
plt.imshow(raw_image, cmap='gray')
plt.colorbar()
plt.title('Raw Chest X Ray Image')
print(f"The dimensions of the image are {raw_image.shape[0]} pixels width and {raw_image.shape[1]} pixels height, one single color channel")
print(f"The maximum pixel value is {raw_image.max():.4f} and the minimum is {raw_image.min():.4f}")
print(f"The mean value of the pixels is {raw_image.mean():.4f} and the standard deviation is {raw_image.std():.4f}")
# Out:
# The dimensions of the image are 128 pixels width and 128 pixels height, one single color channel
# The maximum pixel value is 1.4452 and the minimum is -3.0251
# The mean value of the pixels is 0.0000 and the standard deviation is 1.0000

# %%
# Plot a histogram of the distribution of the pixels
sns.distplot(raw_image.ravel(), 
             label=f'Pixel Mean {np.mean(raw_image):.4f} & Standard Deviation {np.std(raw_image):.4f}', kde=False)
plt.legend(loc='upper center')
plt.title('Distribution of Pixel Intensities in the Image')
plt.xlabel('Pixel Intensity')
plt.ylabel('# Pixels in Image')
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, '# Pixels in Image')

# %%
all_items,dirs,files = next(os.walk(folder_path))

# %%
image_in_classes = []
for i in range(len(dirs)):
    no_of_images =len(os.listdir(os.path.join(folder_path,dirs[i])))
    image_in_classes.append(no_of_images)
df_data = {'class': dirs,'counts': image_in_classes}
classes_df = pd.DataFrame(df_data)

# %%
sns.barplot(x = 'class', y = 'counts',data = classes_df)
plt.title('Class counts')
plt.show()

# %% [markdown]
# # **4. Predictive Modeling**

# %% [markdown]
# ### Using Convolutional Neural Networks

# %%
def plotLearningCurve(history,epochs):
  epochRange = range(1,epochs+1)
  fig, ax = plt.subplots(1,2,figsize=(20,10))
  ax[0].plot(epochRange,history.history['accuracy'],'b',label = 'Training Accuracy')
  ax[0].plot(epochRange,history.history['val_accuracy'],'r',label = 'Validation Accuracy')
  ax[0].set_title('Training and Validation accuracy')
  ax[0].set_xlabel('Epoch', fontsize = 20)
  ax[0].set_ylabel('Accuracy', fontsize = 20)
  ax[0].legend()
  ax[0].grid(color='gray', linestyle='--')
  ax[1].plot(epochRange,history.history['loss'],'b',label = 'Training Loss')
  ax[1].plot(epochRange,history.history['val_loss'],'r',label = 'Validation Loss')
  ax[1].set_title('Training and Validation loss')
  ax[1].set_xlabel('Epoch', fontsize = 20)
  ax[1].set_ylabel('Loss', fontsize = 20)
  ax[1].legend()
  ax[1].grid(color='gray', linestyle='--')
  plt.show()

# %%
def cnn_model(train_data,test_data, epochs,size):
#Building the model using Keras functional API
    print("----Building the model----")
    i = Input(shape=(size,size,3)) #defining input
    x = BatchNormalization()(i)
    x = Conv2D(32,3, activation= 'relu')(i) #adding convolution layers
    x = MaxPooling2D()(x)
    x = Dropout(0.2)(x)
    x = Conv2D(64, 3, activation='relu')(x)
    x = MaxPooling2D()(x)
    x = Dropout(0.2)(x)
    x = Conv2D(128, 3, activation='relu')(x)
    x = MaxPooling2D()(x)
    x = Dropout(0.2)(x)
    x = Flatten()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.1)(x)
    x = Dense(4, activation= 'softmax')(x)

    model = Model(i,x)
    model.summary()
#Training the Convolutional Neural Network
    print("----Training the network----")
    model.compile(optimizer= Adam(0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    
    early_stop = EarlyStopping(monitor='val_loss', 
                               mode='min', 
                               patience = 5 ,
                               restore_best_weights=True)
    #model_checkpoint
    mc = ModelCheckpoint('cnn_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
    r = model.fit(train_data, 
                  validation_data = val_data, 
                  epochs = epochs, 
                  verbose = 2,
                  batch_size = 32,
                  callbacks = [early_stop,mc])
    print("Train score:", model.evaluate(train_data))
    print("Test score:", model.evaluate(val_data))
    n_epochs = len(r.history['loss'])
    
    return r,model,n_epochs

# %%
epochs = 20
r,model,n_epochs = cnn_model(train_data, val_data,epochs,128)
# Out:
# ----Building the model----
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               6422784
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 6,517,060
# Trainable params: 6,517,060
# Non-trainable params: 0
# _________________________________________________________________
# ----Training the network----
# Epoch 1/20
# 464/464 - 151s - loss: 0.7660 - accuracy: 0.6903 - val_loss: 0.6741 - val_accuracy: 0.7867
#
# Epoch 00001: val_loss improved from inf to 0.67415, saving model to cnn_model.h5
# Epoch 2/20
# 464/464 - 56s - loss: 0.5843 - accuracy: 0.7697 - val_loss: 0.5538 - val_accuracy: 0.8116
#
# Epoch 00002: val_loss improved from 0.67415 to 0.55378, saving model to cnn_model.h5
# Epoch 3/20
# 464/464 - 55s - loss: 0.4912 - accuracy: 0.8124 - val_loss: 0.4601 - val_accuracy: 0.8440
#
# Epoch 00003: val_loss improved from 0.55378 to 0.46010, saving model to cnn_model.h5
# Epoch 4/20
# 464/464 - 55s - loss: 0.4244 - accuracy: 0.8399 - val_loss: 0.4778 - val_accuracy: 0.8270
#
# Epoch 00004: val_loss did not improve from 0.46010
# Epoch 5/20
# 464/464 - 55s - loss: 0.3811 - accuracy: 0.8586 - val_loss: 0.3956 - val_accuracy: 0.8617
#
# Epoch 00005: val_loss improved from 0.46010 to 0.39559, saving model to cnn_model.h5
# Epoch 6/20
# 464/464 - 54s - loss: 0.3434 - accuracy: 0.8739 - val_loss: 0.4146 - val_accuracy: 0.8481
#
# Epoch 00006: val_loss did not improve from 0.39559
# Epoch 7/20
# 464/464 - 54s - loss: 0.3106 - accuracy: 0.8857 - val_loss: 0.3952 - val_accuracy: 0.8535
#
# Epoch 00007: val_loss improved from 0.39559 to 0.39522, saving model to cnn_model.h5
# Epoch 8/20
# 464/464 - 54s - loss: 0.2841 - accuracy: 0.8946 - val_loss: 0.3891 - val_accuracy: 0.8573
#
# Epoch 00008: val_loss improved from 0.39522 to 0.38908, saving model to cnn_model.h5
# Epoch 9/20
# 464/464 - 55s - loss: 0.2581 - accuracy: 0.9043 - val_loss: 0.3663 - val_accuracy: 0.8667
#
# Epoch 00009: val_loss improved from 0.38908 to 0.36627, saving model to cnn_model.h5
# Epoch 10/20
# 464/464 - 55s - loss: 0.2314 - accuracy: 0.9145 - val_loss: 0.3565 - val_accuracy: 0.8747
#
# Epoch 00010: val_loss improved from 0.36627 to 0.35651, saving model to cnn_model.h5
# Epoch 11/20
# 464/464 - 54s - loss: 0.2082 - accuracy: 0.9233 - val_loss: 0.3513 - val_accuracy: 0.8741
#
# Epoch 00011: val_loss improved from 0.35651 to 0.35127, saving model to cnn_model.h5
# Epoch 12/20
# 464/464 - 54s - loss: 0.1935 - accuracy: 0.9282 - val_loss: 0.3733 - val_accuracy: 0.8729
#
# Epoch 00012: val_loss did not improve from 0.35127
# Epoch 13/20
# 464/464 - 54s - loss: 0.1672 - accuracy: 0.9388 - val_loss: 0.3828 - val_accuracy: 0.8708
#
# Epoch 00013: val_loss did not improve from 0.35127
# Epoch 14/20
# 464/464 - 54s - loss: 0.1531 - accuracy: 0.9447 - val_loss: 0.4151 - val_accuracy: 0.8653
#
# Epoch 00014: val_loss did not improve from 0.35127
# Epoch 15/20
# 464/464 - 54s - loss: 0.1331 - accuracy: 0.9509 - val_loss: 0.3809 - val_accuracy: 0.8810
#
# Epoch 00015: val_loss did not improve from 0.35127
# Epoch 16/20
# 464/464 - 55s - loss: 0.1242 - accuracy: 0.9542 - val_loss: 0.4430 - val_accuracy: 0.8650
#
# Epoch 00016: val_loss did not improve from 0.35127
# 464/464 [==============================] - 39s 85ms/step - loss: 0.1801 - accuracy: 0.9351
# Train score: [0.18006473779678345, 0.9351464509963989]
# 199/199 [==============================] - 16s 83ms/step - loss: 0.3513 - accuracy: 0.8741
# Test score: [0.35127121210098267, 0.8741137385368347]

# %%
plotLearningCurve(r,n_epochs)

# %%
# printing model accuracy for train and test data
test_evaluation = model.evaluate(val_data)
print(f"Test Accuracy using CNN: {test_evaluation[1] * 100:.2f}%")

train_evaluation = model.evaluate(train_data)
print(f"Train Accuracy using CNN: {train_evaluation[1] * 100:.2f}%")
# Out:
# 199/199 [==============================] - 17s 85ms/step - loss: 0.3513 - accuracy: 0.8741
# Test Accuracy using CNN: 87.41%
# 464/464 [==============================] - 39s 84ms/step - loss: 0.1801 - accuracy: 0.9351
# Train Accuracy using CNN: 93.51%

# %% [markdown]
# ### Using Resnet

# %%
def resnet_model(train_data,test_data, epochs,size):
#Building the model using Keras functional API
    print("----Building the model----")
    
    base_model = ResNet50(input_shape= (size,size,3), include_top=False)
#     base_model.trainable=False #freezing the layer


    x=base_model.output
    x=GlobalAveragePooling2D()(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    out=Dense(4,activation='softmax')(x)

    model=Model(inputs=base_model.input,outputs=out) 
    # model.summary()
#Training the Convolutional Neural Network
    print("----Training the network----")
    model.compile(optimizer= Adam(0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
    
    early_stop = EarlyStopping(monitor='val_loss', 
                               mode='min', 
                               patience = 5 ,
                               restore_best_weights=True)
    #model_checkpoint
    mc = ModelCheckpoint('resnet_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
    r = model.fit(train_data, 
                  validation_data = val_data, 
                  epochs = epochs, 
                  verbose = 2,
                  batch_size = 32,
                  callbacks = [early_stop,mc])
    print("Train score:", model.evaluate(train_data))
    print("Test score:", model.evaluate(val_data))
    n_epochs = len(r.history['loss'])
    
    return r,model,n_epochs

# %%
epochs = 10
r,model,n_epochs = resnet_model(train_data, val_data,epochs,128)
# Out:
# ----Building the model----
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 0s 0us/step
# ----Training the network----
# Epoch 1/10
# 464/464 - 71s - loss: 0.3289 - accuracy: 0.8758 - val_loss: 1.2132 - val_accuracy: 0.4308
#
# Epoch 00001: val_loss improved from inf to 1.21315, saving model to resnet_model.h5
# Epoch 2/10
# 464/464 - 66s - loss: 0.1490 - accuracy: 0.9443 - val_loss: 0.2796 - val_accuracy: 0.8946
#
# Epoch 00002: val_loss improved from 1.21315 to 0.27963, saving model to resnet_model.h5
# Epoch 3/10
# 464/464 - 64s - loss: 0.1029 - accuracy: 0.9615 - val_loss: 0.2174 - val_accuracy: 0.9311
#
# Epoch 00003: val_loss improved from 0.27963 to 0.21743, saving model to resnet_model.h5
# Epoch 4/10
# 464/464 - 64s - loss: 0.0883 - accuracy: 0.9681 - val_loss: 0.2060 - val_accuracy: 0.9340
#
# Epoch 00004: val_loss improved from 0.21743 to 0.20595, saving model to resnet_model.h5
# Epoch 5/10
# 464/464 - 66s - loss: 0.0446 - accuracy: 0.9843 - val_loss: 0.2023 - val_accuracy: 0.9401
#
# Epoch 00005: val_loss improved from 0.20595 to 0.20225, saving model to resnet_model.h5
# Epoch 6/10
# 464/464 - 65s - loss: 0.0425 - accuracy: 0.9856 - val_loss: 0.3083 - val_accuracy: 0.9157
#
# Epoch 00006: val_loss did not improve from 0.20225
# Epoch 7/10
# 464/464 - 64s - loss: 0.0393 - accuracy: 0.9870 - val_loss: 0.2740 - val_accuracy: 0.9152
#
# Epoch 00007: val_loss did not improve from 0.20225
# Epoch 8/10
# 464/464 - 64s - loss: 0.0346 - accuracy: 0.9885 - val_loss: 0.3017 - val_accuracy: 0.9332
#
# Epoch 00008: val_loss did not improve from 0.20225
# Epoch 9/10
# 464/464 - 64s - loss: 0.0503 - accuracy: 0.9821 - val_loss: 0.2247 - val_accuracy: 0.9382
#
# Epoch 00009: val_loss did not improve from 0.20225
# Epoch 10/10
# 464/464 - 65s - loss: 0.0266 - accuracy: 0.9910 - val_loss: 0.2859 - val_accuracy: 0.9173
#
# Epoch 00010: val_loss did not improve from 0.20225
# 464/464 [==============================] - 43s 93ms/step - loss: 0.0282 - accuracy: 0.9918
# Train score: [0.028187166899442673, 0.991834282875061]
# 199/199 [==============================] - 19s 96ms/step - loss: 0.2023 - accuracy: 0.9401
# Test score: [0.20225206017494202, 0.9401292204856873]

# %%
plotLearningCurve(r,n_epochs)

# %%
# printing model accuracy for train and test data
test_evaluation = model.evaluate(val_data)
print(f"Test Accuracy using ResNet50: {test_evaluation[1] * 100:.2f}%")

train_evaluation = model.evaluate(train_data)
print(f"Train Accuracy using ResNet50: {train_evaluation[1] * 100:.2f}%")
# Out:
# 199/199 [==============================] - 18s 90ms/step - loss: 0.2023 - accuracy: 0.9401
# Test Accuracy using ResNet50: 94.01%
# 464/464 [==============================] - 43s 94ms/step - loss: 0.0282 - accuracy: 0.9918
# Train Accuracy using ResNet50: 99.18%

# %% [markdown]
# ###
